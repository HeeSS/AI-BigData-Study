# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/title.png' width=500/></center>

# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/practice.png' width=300/></center>

# %% [markdown]
# # 실습 목표
#
# - CSV 파일에서 데이터를 읽어올 수 있습니다.
# - 결측치를 확인하고 제거하거나 다른 값으로 채울 수 있습니다.
# - 가변수를 만들 수 있습니다.
# - 데이터 표준화와 정규화를 할 수 있습니다.

# %% [markdown]
# # P5. 데이터프레임 변경(2)

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 모듈 불러오기
from sklearn.datasets import fetch_openml

# 데이터 불러오기
x, y = fetch_openml('titanic', version=1, as_frame=True, return_X_y=True)

# %% [markdown]
# 1) x 데이터프레임과 y 시리즈를 합쳐 titanic 데이터프레임을 만드세요.

# %% [markdown]
# 2) titanic 데이터프레임에서 name, ticket, boat, body, home.dest 열을 제거하세요.

# %% [markdown]
# 3) 각 열마다 결측치가 몇 개씩 있는지 확인하세요.

# %% [markdown]
# 4) cabin 열의 결측치를 'X'로 채우세요.

# %% [markdown]
# 5) cabin 열이 문자열 첫 글자(예: C22 --> C)만 갖도록 변경하세요.

# %% [markdown]
# 6) embarked 열의 결측치를 'S'로 채우세요.

# %% [markdown]
# 7) age 열의 결측치를 age 열의 평균으로 채우세요.

# %% [markdown]
# 8) fare 열의 결측치를 fare 열 중앙값으로 채우세요.

# %% [markdown]
# 9) sinsp 열과 parch 열 합을 갖는 family 열을 추가하고 sinsp 열과 parch 열은 제거하세요.

# %% [markdown]
# 10) 다음 구간별 값을 갖도록 family 열을 변경하세요.
#
# - 구간과 값: 0 ~ 1 --> A / 2 ~ 4 --> B / 5 ~ --> C

# %% [markdown]
# 11) 다음 열에 대한 가변수화 처리를 하세요.
#
# - pclass, sex, cabin, embarked, family

# %% [markdown]
# 12) age, fare 열 값이 0과 1 사이의 값을 갖도록 정규화 작업을 진행하세요.

# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/end.png' width=300/></center>
