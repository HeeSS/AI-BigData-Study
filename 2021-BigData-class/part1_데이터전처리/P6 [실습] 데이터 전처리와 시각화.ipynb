# %% [markdown]
# # **Iris 데이터를 이용한 <span style="color:darkgreen">전처리 & 시각화</span> 문제**
# ---

# %% [markdown]
# > **<span style="color:red">다음 문항을 풀기 전에 </span>아래 코드를 실행하시오.**<br>
# > 반드시 코드와 주석을 읽고 문제를 푸시오. <br>
# > 반드시 출력된 데이터 설명을 읽고 문제를 푸시오.
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris = load_iris()

x = iris.data # 넘파이 어레이, 인풋으로 사용할 변수들
y = iris.target # 넘파이 어레이, 아웃풋으로 사용할 변수

print(iris.feature_names) # 컬럼명이 담겨 있다.
print(iris.target_names) # 클래스명이 담겨 있다. ( ex> y가 2라면 virginica, 1이라면 versicolor )

print(iris.DESCR)

# %% [markdown]
# # Q1. x와 y를 하나의 데이터프레임으로 만들어 data에 선언하시오.
#
# ----------------
# 1. 컬럼명은 주어진 feature_names를 약간 변형하여 아래와 같이 한다.
#     - sepal_length, sepal_width, petal_length, petal_width
# 2. y의 컬럼명은 class로 한다.
# -----------------

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # Q2. 다음 조건에 맞추어 data안에 새로운 컬럼 virginica를 만드시오.
# -----------
# * virginica 면 1, 그렇지 않으면 0 이 담겨야 한다.
# * target_names를 참고
# -----------

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # Q3. 다음 조건에 맞추어 data안에 새로운 컬럼 feature_sum 을 만드시오.
# ----------------------
# * feature_sum은 sepal의 length와 width, petal의 length와 width의 합으로 정의한다.
# --------------------

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # Q4. feature_sum 컬럼의 변화에 따른 class 컬럼의 변화를 시각화 하시오.
# ----------------------
# * 설명변수와 반응변수의 관계를 시각화 하는 것이다
# * 기본적으로는 scatter plot을 사용한다.
# * 기타 다른 적절한 시각화 기법을 사용해도 좋다.
#     - 단, 그 이유를 주석으로 명시해야 한다.
# --------------------

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # Q5. 다음 조건에 맞추어 data안에 새로운 컬럼 feature_mul을 만드시오.
# ----------------------
# * feature_mul은 sepal의 length와 width, petal의 length와 width 총 4개 컬럼의 곱으로 정의한다.
# --------------------

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # Q6. feature_mul 컬럼의 변화에 따른 class 컬럼의 변화를 시각화 하시오.
# ----------------------
# * 설명변수와 반응변수의 관계를 시각화 하는 것이다
# * 기본적으로는 scatter plot을 사용한다.
# * 기타 다른 적절한 시각화 기법을 사용해도 좋다.
#     - 단, 그 이유를 주석으로 명시해야 한다.
# --------------------

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # Q7. 다음 조건에 맞추어 data안에 새로운 컬럼 pw_group을 만드시오.
# -----------------
# * 기본적으로 petal width를 binning하여 새로운 컬럼을 만드는 것이다.
# * petal width 컬럼의 25% 이하일 때는 'a'
# * petal width 컬럼의 25% 초과, 50% 이하일 때는 'b'
# * petal width 컬럼의 50% 초과, 75% 이하일 때는 'c'
# * petal width 컬럼의 75% 초과일 때는 'd'
# ----------------------

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # Q8. petal_width의 그룹별(pw_group)로 class컬럼의 각 그룹의 개수를 카운트하여 출력하시오.
# -----------------
# * 설명변수와 반응변수의 관계를 요약 하는 것이다
# * pw_group 4개 그룹 * class 3개 그룹 : 총 12개 그룹의 카운팅이 되어야 한다.
# ------------------------

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # Q9. 다음 조건에 맞추어 data안에 새로운 컬럼 sl_group을 만드시오.
# -----------------
# * 기본적으로 sepal length를 binning하여 새로운 컬럼을 만드는 것이다.
# * sepal length 컬럼의 50% 이하일 때는 's'
# * sepal length 컬럼의 50% 초과일 때는 'l'
# ----------------------

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # Q10. sl_group이 's'일 때, pw_group 별로 virginica의 비율을 계산하여 출력하시오.
# ------------------------------
# * 설명변수와 반응변수의 관계를 시각화 하는 것이다
# * virginica 컬럼을 이용하면 편리하다.
# --------------------------------

# %%
####################
## Your code here ##
####################
