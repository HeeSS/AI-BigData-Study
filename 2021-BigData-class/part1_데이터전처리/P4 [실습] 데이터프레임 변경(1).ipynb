# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/title.png' width=500/></center>

# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/practice.png' width=300/></center>

# %% [markdown]
# # 실습 목표
#
# - CSV 파일에서 데이터를 읽어올 수 있습니다.
# - 불필요한 열을 제거할 수 있습니다.
# - 기존 열의 값을 바꿀 수 있습니다.
# - 기존 열에 대한 계산 결과를 갖는 새로운 열을 추가할 수 있습니다.
# - 열 이름을 바꿀 수 있습니다.

# %% [markdown]
# # P4. 데이터프레임 변경(1)

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1) 'titanic_simple.csv' 파일을 불러와 데이터프레임 **titanic**을 만드세요.
#
# - 파일 경로: 'https://raw.githubusercontent.com/Jangrae/csv/master/titanic_train.csv'

# %% [markdown]
# 2) Name, PassengerId, Ticket 열을 삭제하세요.

# %% [markdown]
# 3) Fare 열 값의 분포를 Histogram으로 시각화해 확인하세요.
#
# - 빈도(Frequancy)로 확인하고 밀도(Density)로도 확인하세요.
# - bins 는 20으로 지정하세요.

# %% [markdown]
# 4) titanic.describe() 조회 결과에서 Fare의 25%, 50%, 75% 값을 q1, q2, q3 변수로 선언하세요.

# %% [markdown]
# 5) 위에서 얻은 q1, q2, q3 값을 사용해 다음과 같이 정해진 구간에 따라 A, B, C, D 값을 갖는 FareGrp 열을 추가하세요.
#
#   - 25% 이하 → A
#   - 25% 초과 50% 이하 → B
#   - 50% 초과 75% 이하 → C
#   - 75% 초과 → D

# %% [markdown]
# 6) FareGrp 별 Fare와 Age 표준편차를 집계하세요.

# %% [markdown]
# 7) Sex 열이 'female', 'male' 대신 0, 1을 갖도록 변경하세요.

# %% [markdown]
# 8) Cabin열이 Cabin 열의 첫 글자만 갖도록 값을 변경하세요.

# %% [markdown]
# 9) Cabin 열 값이 NaN 인 경우 'X' 값을 갖도록 변경하세요.

# %% [markdown]
# 10) Age를 x축, Fare를 y축으로하여 상관관계를 산점도로 표시하세요.

# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/end.png' width=300/></center>
